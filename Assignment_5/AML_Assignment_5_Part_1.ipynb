# %% [markdown]
# ## Vikas Chaudhary
# ### MDS202353

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
# Install required packages
# !pip install -q split-folders

# %%
# !pip install bing-image-downloader
# Out:
# Collecting bing-image-downloader
#   Downloading bing_image_downloader-1.1.2-py3-none-any.whl.metadata (2.8 kB)
# Downloading bing_image_downloader-1.1.2-py3-none-any.whl (5.9 kB)
# Installing collected packages: bing-image-downloader
# Successfully installed bing-image-downloader-1.1.2

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
import numpy as np
import matplotlib.pyplot as plt
import os
import random
from PIL import Image

# %%
from bing_image_downloader import downloader
downloader.download("chicken bird", limit=100, output_dir='images', adult_filter_off=True, force_replace=False, timeout=60)
downloader.download("duck bird", limit=100, output_dir='images', adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# [%] Downloading Images to /content/images/chicken bird
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://pixnio.com/free-images/2020/07/03/2020-07-03-10-41-06.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.thoughtco.com/thmb/kAa1KovfJfcpMICKMPXoHF5IhuM=/2500x1674/filters:fill(auto,1)/red_junglefowl-5968fedd5f9b582c356ab7fb.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.britannica.com/18/137318-050-29F7072E/rooster-Rhode-Island-Red-roosters-chicken-domestication.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.pixabay.com/photo/2014/07/31/13/36/chicken-406312_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.pinimg.com/originals/f2/77/d2/f277d2162da9af687fa7182f8dd2ecca.png
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://cdn.pixabay.com/photo/2021/01/07/06/43/hen-5896345_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://pixnio.com/free-images/2018/06/14/2018-06-14-22-46-33.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://cdn.britannica.com/07/183407-050-C35648B5/Chicken.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://external-preview.redd.it/-S2Ca7QYtYGLJ9M2Q17ngjkPcUEsGEwxHBnph44Oo_w.jpg?auto=webp&amp;s=a4bcb8d160488d11ffbc3a86b36ab0f72f789700
# [!] Issue getting: https://external-preview.redd.it/-S2Ca7QYtYGLJ9M2Q17ngjkPcUEsGEwxHBnph44Oo_w.jpg?auto=webp&amp;s=a4bcb8d160488d11ffbc3a86b36ab0f72f789700
# [!] Error:: HTTP Error 403: Blocked
# [%] Downloading Image #9 from https://a-z-animals.com/media/2019/11/Chicken-2-hens.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://get.pxhere.com/photo/bird-barn-home-village-beak-chicken-fowl-fauna-rooster-poultry-cock-family-galliformes-vertebrate-yard-phasianidae-590431.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://cdn.pixabay.com/photo/2022/03/03/16/00/chicken-7045624_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://a-z-animals.com/media/2021/12/Best-farm-animals-Chicken.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://get.pxhere.com/photo/nature-bird-farm-prairie-animal-beak-chicken-fowl-fauna-rooster-poultry-cock-animals-galliformes-vertebrate-phasianidae-617343.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://facts.net/wp-content/uploads/2020/01/sven-hornburg-Jgabeh9Yx6w-unsplash.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://get.wallhere.com/photo/birds-red-rooster-Chicken-beak-chickens-roosters-flower-bird-fauna-comb-vertebrate-close-up-fowl-poultry-galliformes-phasianidae-291207.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://i.pinimg.com/originals/5d/52/47/5d524708babf231be79fd7e339a35646.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://get.pxhere.com/photo/bird-animal-beak-macro-chicken-fowl-avian-fauna-rooster-poultry-feathers-galliformes-vertebrate-phasianidae-1268173.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://img.freepik.com/premium-photo/chicken-bird_1048944-1062288.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://img.freepik.com/premium-photo/chicken-bird_1048944-14035684.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://c0.wallpaperflare.com/preview/44/301/235/chicken-hen-running-animal.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://9b16f79ca967fd0708d1-2713572fef44aa49ec323e813b06d2d9.ssl.cf2.rackcdn.com/1140x_a10-7_cTC/20150724HORedJunglefowlHen-2-1567794297.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://cdn.pixabay.com/photo/2016/04/07/21/59/chicken-1314888_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://c1.wallpaperflare.com/preview/598/102/441/chicken-breed-chicken-bird-agriculture.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://static.photocrowd.com/photos/3168168-20dcd28116a5a3d0468f44a71e7584bf5fb29aa2-hd.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://coolwallpapers.me/picsup/3069286-animal_avian_beak_bird_chicken_close-up_cockscomb_domestic_farm_feather_fowl_hen_livestock_poultry_white.jpg
# [!] Issue getting: https://coolwallpapers.me/picsup/3069286-animal_avian_beak_bird_chicken_close-up_cockscomb_domestic_farm_feather_fowl_hen_livestock_poultry_white.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #25 from https://get.pxhere.com/photo/nature-bird-wing-white-red-beak-chicken-rooster-plumage-hen-close-up-galliformes-vertebrate-phasianidae-comb-823785.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://cdn.pixabay.com/photo/2020/03/02/21/14/chicken-4896969_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://c1.wallpaperflare.com/preview/625/47/691/chicken-breed-chicken-bird-agriculture.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://img.freepik.com/premium-photo/chicken-bird_1048944-939095.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://cdn.pixabay.com/photo/2022/03/03/15/52/chicken-7045604_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://cdn.pixabay.com/photo/2020/07/31/21/03/hen-5454091_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #31 from https://get.pxhere.com/photo/bird-farm-village-beak-chicken-fauna-poultry-close-up-birds-duck-galliformes-vertebrate-chick-water-bird-541304.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #32 from https://img.freepik.com/premium-photo/chicken-bird_1048944-4631496.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #33 from https://www.thespruce.com/thmb/kd8OzJNr1ZX_kpiMdvoA5IBSnCE=/1280x853/filters:no_upscale():max_bytes(150000):strip_icc()/Ameraucana-resized-56a885833df78cf7729e882c.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #34 from https://i.pinimg.com/originals/9e/41/d9/9e41d90f8ad6339f133dbc121abb03b8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #35 from https://cdn.pixabay.com/photo/2021/01/07/06/43/hen-5896345_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #36 from https://a-z-animals.com/media/2019/11/Chicken-rooster-in-grass.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #37 from https://cdn.pixabay.com/photo/2022/12/29/11/07/bird-7684694_1280.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 35 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #38 from https://www.thoughtco.com/thmb/UJhN7lBjA1B8lxVXupG8XfHoB04=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/red_junglefowl-5968fedd5f9b582c356ab7fb.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 35 Images on Page 5.
#
# ===============================================
#
# [%] Downloading Image #39 from https://img.freepik.com/premium-photo/chicken-bird_1048944-2709479.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #40 from https://scx2.b-cdn.net/gfx/news/hires/2020/hen.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 35 Images on Page 6.
#
# ===============================================
#
# [%] Downloading Image #41 from https://d2j6dbq0eux0bg.cloudfront.net/images/12968799/3565914492.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 7
#
# [%] Indexed 35 Images on Page 7.
#
# ===============================================
#
# [%] Downloading Image #42 from https://cdn.pixabay.com/photo/2022/03/06/10/33/chicken-7051326_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #43 from https://img.freepik.com/premium-photo/chicken-bird_1048944-565151.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 35 Images on Page 8.
#
# ===============================================
#
# [%] Downloading Image #44 from https://i.pinimg.com/originals/ba/50/63/ba5063aaca699601e5754a8de338e6be.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 35 Images on Page 9.
#
# ===============================================
#
# [%] Downloading Image #45 from https://img.freepik.com/premium-photo/chicken-bird_1048944-11733889.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 10
#
# [%] Indexed 35 Images on Page 10.
#
# ===============================================
#
# [%] Downloading Image #46 from http://www.pixelstalk.net/wp-content/uploads/2016/10/Animals-Birds-Chicken-with-open-beak-wallpapers.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #47 from https://www.thoughtco.com/thmb/_Jh0GHt9kV3v36-I_3lqNnswfmk=/768x0/filters:no_upscale():max_bytes(150000):strip_icc()/red_junglefowl-5968fedd5f9b582c356ab7fb.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 11
#
# [%] Indexed 35 Images on Page 11.
#
# ===============================================
#
# [%] Downloading Image #48 from http://www.crodog.org/photos/birds/images/chicken_jpg.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 12
#
# [%] Indexed 35 Images on Page 12.
#
# ===============================================
#
# [%] Downloading Image #49 from https://animaldiversity.org/collections/contributors/ryan_fanshaw/Ggallus1/medium.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #50 from https://upload.wikimedia.org/wikipedia/commons/8/84/Male_and_female_chicken_sitting_together.jpg?Gallus_gallus_domesticus207787177
# [%] File Downloaded !
#
# [%] Downloading Image #51 from https://thumbs.dreamstime.com/b/gallus-gallus-27947834.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #52 from https://get.pxhere.com/photo/bird-red-beak-color-chicken-rooster-poultry-close-up-eye-galliformes-vertebrate-phasianidae-comb-808025.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #53 from https://www.shutterstock.com/shutterstock/photos/1833026635/display_1500/stock-photo-beautiful-domestic-fowl-gallus-gallus-local-breed-in-asia-they-show-their-beauty-1833026635.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #54 from https://jnt.nz/wp-content/uploads/2018/10/500_0528.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #55 from https://i.pinimg.com/originals/01/1c/63/011c6359c09afd5b9f83e6d0e22bd8b4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #56 from https://i.pinimg.com/originals/8d/67/cc/8d67cc275ef6952ad13431d1803c7ed4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #57 from https://s-media-cache-ak0.pinimg.com/originals/c7/44/bd/c744bdc28249614e44817b85a8772385.png
# [%] File Downloaded !
#
# [%] Downloading Image #58 from http://image.shutterstock.com/z/stock-photo-the-chicken-gallus-gallus-or-gallus-domesticus-sina-linnaeus-is-a-domestic-bird-arising-76466524.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #59 from https://i.pinimg.com/originals/52/ce/aa/52ceaa39ee8485327ac014a94ee12ad1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #60 from https://cdn.pixabay.com/photo/2021/09/11/06/12/chicken-6614769_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #61 from http://animaldiversity.org/collections/contributors/david_blank/gallus2/medium.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #62 from https://animaldiversity.org/collections/contributors/corel_cd/white_chicken/medium.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #63 from https://plantsam.com/animals/wp-content/uploads/sites/10/2021/12/Gallus-gallusdomesticus.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #64 from https://vignette.wikia.nocookie.net/animalhistory/images/6/6d/Rooster_800.jpg/revision/latest?cb=20120411031255
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 13
#
# [%] Indexed 35 Images on Page 13.
#
# ===============================================
#
# [%] Downloading Image #65 from https://cdn.pixabay.com/photo/2022/09/05/01/09/chicken-7433011_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #66 from https://get.pxhere.com/photo/nature-bird-white-rural-farming-beak-livestock-agriculture-feather-chicken-birds-animals-galliformes-turkey-eggs-vertebrate-domestic-chickens-phasianidae-barnyard-poultry-farm-domesticated-turkey-564042.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #67 from https://get.pxhere.com/photo/grass-bird-village-chicken-fowl-rooster-poultry-hen-cock-birds-galliformes-vertebrate-chickens-phasianidae-elitexpo-subsistence-farming-chicken-family-kura-560443.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 14
#
# [%] Indexed 35 Images on Page 14.
#
# ===============================================
#
#
#
# [!!]Indexing page: 15
#
# [%] Indexed 35 Images on Page 15.
#
# ===============================================
#
# [%] Downloading Image #68 from https://cdn.pixabay.com/photo/2024/05/19/16/53/chicken-8772930_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #69 from https://c1.wallpaperflare.com/preview/756/90/560/chicken-breed-chicken-bird-agriculture.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #70 from https://cdn.pixabay.com/photo/2018/08/08/07/29/chicken-3591496_960_720.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 16
#
# [%] Indexed 35 Images on Page 16.
#
# ===============================================
#
# [%] Downloading Image #71 from https://i.pinimg.com/736x/f2/77/d2/f277d2162da9af687fa7182f8dd2ecca.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 17
#
# [%] Indexed 35 Images on Page 17.
#
# ===============================================
#
# [%] Downloading Image #72 from https://cdn.vox-cdn.com/thumbor/AjUeS-jb1xiEF0m_y6YDcZrfczQ=/1400x1400/filters:format(jpeg)/cdn.vox-cdn.com/uploads/chorus_asset/file/23432577/GettyImages_1225752997__1_.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #73 from https://c8.alamy.com/comp/D2AR5P/domestic-chicken-gallus-gallus-domesticus-hen-portrait-at-poultry-D2AR5P.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #74 from https://aviancontrolinc.com/wp-content/uploads/2023/02/Flock-of-chickens-running-on-grass-scaled.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #75 from https://pixnio.com/free-images/2018/06/14/2018-06-14-22-46-18.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 18
#
# [%] Indexed 35 Images on Page 18.
#
# ===============================================
#
# [%] Downloading Image #76 from https://get.pxhere.com/photo/grass-bird-prairie-animal-beak-chicken-fauna-poultry-hen-galliformes-vertebrate-chick-chickens-phasianidae-chicken-farm-643130.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #77 from https://a-z-animals.com/media/2022/11/shutterstock_1730264416-2048x1362.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 19
#
# [%] Indexed 35 Images on Page 19.
#
# ===============================================
#
#
#
# [!!]Indexing page: 20
#
# [%] Indexed 35 Images on Page 20.
#
# ===============================================
#
# [%] Downloading Image #78 from https://get.pxhere.com/photo/bird-farm-animal-beak-macro-chicken-fowl-fauna-rooster-poultry-close-up-galliformes-vertebrate-phasianidae-comb-animal-photography-1365951.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #79 from https://www.pixelstalk.net/wp-content/uploads/2016/10/Animals-Birds-Chicken-with-open-beak-wallpapers.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #80 from https://animaldiversity.org/collections/contributors/david_blank/gallus6/medium.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #81 from https://c8.alamy.com/comp/BH9M4X/chicken-gallus-gallus-domesticus-BH9M4X.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #82 from https://a-z-animals.com/media/animals/images/original/chicken1-600x400.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #83 from https://www.underwaterkwaj.com/land/bird-kwaj/Gallus-gallus-k02-161221.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 21
#
# [%] Indexed 35 Images on Page 21.
#
# ===============================================
#
# [%] Downloading Image #84 from https://wallup.net/wp-content/uploads/2017/03/28/449785-photography-Chicken-birds-animals-closeup.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #85 from https://media.istockphoto.com/id/1352999139/photo/portrait-of-chicken-bird-in-sky-background.jpg?s=170667a&amp;w=0&amp;k=20&amp;c=X7gJ4gVsDBpybDOvI3l9S7IafNzmhaf14_nveTy-8Bw=
# [!] Issue getting: https://media.istockphoto.com/id/1352999139/photo/portrait-of-chicken-bird-in-sky-background.jpg?s=170667a&amp;w=0&amp;k=20&amp;c=X7gJ4gVsDBpybDOvI3l9S7IafNzmhaf14_nveTy-8Bw=
# [!] Error:: HTTP Error 400: Bad Request
#
#
# [!!]Indexing page: 22
#
# [%] Indexed 35 Images on Page 22.
#
# ===============================================
#
# [%] Downloading Image #85 from https://cdn.pixabay.com/photo/2023/12/11/22/28/chicken-8444590_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #86 from https://cdn.pixabay.com/photo/2022/03/03/15/58/chicken-7045615_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #87 from https://a-z-animals.com/media/2019/11/Chicken-chicks-on-log.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 23
#
# [%] Indexed 35 Images on Page 23.
#
# ===============================================
#
# [%] Downloading Image #88 from https://pixy.org/src2/643/thumbs350/6432190.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 24
#
# [%] Indexed 35 Images on Page 24.
#
# ===============================================
#
# [%] Downloading Image #89 from https://img.freepik.com/premium-photo/chicken-gallus-gallus-domesticus_621486-6388.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #90 from https://static.vecteezy.com/system/resources/previews/019/572/966/large_2x/rooster-chicken-bird-animal-pet-healthy-poultry-free-photo.jpg
# [!] Issue getting: https://static.vecteezy.com/system/resources/previews/019/572/966/large_2x/rooster-chicken-bird-animal-pet-healthy-poultry-free-photo.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #90 from https://c8.alamy.com/comp/X4C58M/chicken-gallus-gallus-domesticus-X4C58M.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 25
#
# [%] Indexed 35 Images on Page 25.
#
# ===============================================
#
# [%] Downloading Image #91 from https://img.freepik.com/premium-photo/chicken-bird_1048944-20033385.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 26
#
# [%] Indexed 35 Images on Page 26.
#
# ===============================================
#
# [%] Downloading Image #92 from https://images.pexels.com/photos/322702/pexels-photo-322702.jpeg?cs=srgb&amp;dl=chicken-bird-chickens-animal-birds-feathers-322702.jpg&amp;fm=jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 27
#
# [%] Indexed 35 Images on Page 27.
#
# ===============================================
#
# [%] Downloading Image #93 from https://cdn.pixabay.com/photo/2024/04/30/18/59/chicken-8730828_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #94 from https://cdn.pixabay.com/photo/2020/11/02/17/21/chicken-5707371_640.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 28
#
# [%] Indexed 35 Images on Page 28.
#
# ===============================================
#
# [%] Downloading Image #95 from http://4.bp.blogspot.com/-HmFMHsI0ddw/UrRjDdvDVqI/AAAAAAAABa8/-Tj3-Gcfje0/s1600/Poultry+Birds.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 29
#
# [%] Indexed 35 Images on Page 29.
#
# ===============================================
#
# [%] Downloading Image #96 from https://www.thespruce.com/thmb/L7txxGBqaNnqWJO2sMb-hhYecd4=/1280x853/filters:fill(auto,1)/Ameraucana-resized-56a885833df78cf7729e882c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #97 from https://cdn.pixabay.com/photo/2017/08/16/14/53/chicken-2648030_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #98 from https://www.pngmart.com/files/22/Chicken-Bird-PNG-Photos.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 30
#
# [%] Indexed 35 Images on Page 30.
#
# ===============================================
#
#
#
# [!!]Indexing page: 31
#
# [%] Indexed 35 Images on Page 31.
#
# ===============================================
#
# [%] Downloading Image #99 from https://cdn.pixabay.com/photo/2023/09/10/13/43/chicken-8244993_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #100 from https://learnpoultry.com/wp-content/uploads/2023/04/what-is-a-chicken.webp
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 100 images.
# [%] Downloading Images to /content/images/duck bird
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://i2.wp.com/passnownow.com/wp-content/uploads/2015/06/duck.jpg?fit=2000%2C1339&amp;ssl=1
# [!] Issue getting: https://i2.wp.com/passnownow.com/wp-content/uploads/2015/06/duck.jpg?fit=2000%2C1339&amp;ssl=1
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #1 from https://coolwallpapers.me/picsup/3055448-animal_animal-portrait_animal-world_aquatic-animal_bird_close_drake_duck_duck-bird_duck-head_fauna_female_head_male_males_mallard_nature_pair-of-ducks_plumage_poultry_species_water-bird_waterfowl.jpg
# [!] Issue getting: https://coolwallpapers.me/picsup/3055448-animal_animal-portrait_animal-world_aquatic-animal_bird_close_drake_duck_duck-bird_duck-head_fauna_female_head_male_males_mallard_nature_pair-of-ducks_plumage_poultry_species_water-bird_waterfowl.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #1 from https://pixnio.com/free-images/2019/03/15/2019-03-15-11-38-43.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn.britannica.com/92/100692-050-5B69B59B/Mallard.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://pixnio.com/free-images/2017/11/02/2017-11-02-17-19-53.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://hawaiibirdingtrails.hawaii.gov/wp-content/uploads/Muscovy-Duck-female_Michelle-Moore.jpg
# [Error]Invalid image, not saving https://hawaiibirdingtrails.hawaii.gov/wp-content/uploads/Muscovy-Duck-female_Michelle-Moore.jpg
#
# [!] Issue getting: https://hawaiibirdingtrails.hawaii.gov/wp-content/uploads/Muscovy-Duck-female_Michelle-Moore.jpg
# [!] Error:: Invalid image, not saving https://hawaiibirdingtrails.hawaii.gov/wp-content/uploads/Muscovy-Duck-female_Michelle-Moore.jpg
#
# [%] Downloading Image #4 from https://pixnio.com/free-images/fauna-animals/birds/duck-mallard-pictures/wood-ducks/close-up-high-detailed-photograph-of-male-wood-duck-waterfowl-bird-in-water-aix-sponsa.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://images.pexels.com/photos/605780/pexels-photo-605780.jpeg?cs=srgb&amp;dl=duck-duck-bird-605780.jpg&amp;fm=jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://get.pxhere.com/photo/water-winter-bird-animal-wildlife-wild-beak-fauna-duck-animals-vertebrate-ducks-waterfowl-water-bird-mallard-canard-wild-birds-crossword-bird-duck-kaczor-ducks-geese-and-swans-seaduck-987874.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://pixnio.com/free-images/2017/10/30/2017-10-30-16-46-18.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://get.pxhere.com/photo/bird-wildlife-beak-shine-fauna-poultry-drake-close-up-anatidae-duck-head-vertebrate-bill-waterfowl-species-water-bird-mallard-canard-males-metallic-bluish-duck-bird-blue-metallic-anas-platyrhynchos-neck-ring-swimming-duck-ducks-geese-and-swans-white-collar-march-duck-house-duck-1100867.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://wallup.net/wp-content/uploads/2018/10/09/982783-animal-cute-baby-beauty-lake-water-bird-duck-duck.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://wallup.net/wp-content/uploads/2019/10/363761-mandarin-duck-bird-ducks-68.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://usercontent2.hubstatic.com/7280919_f1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://cdn.pixabay.com/photo/2023/05/13/23/47/bird-7991687_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://wallup.net/wp-content/uploads/2016/01/54709-duck-birds-split_view-baby_animals-water.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://images.squarespace-cdn.com/content/v1/587d6250d482e9eee8c47666/1496644640891-S0V62M24QA0AUAKA9S5F/ke17ZwdGBToddI8pDm48kA_SSaoz4elkj-HsZd8gX3Z7gQa3H78H3Y0txjaiv_0fDoOvxcdMmMKkDsyUqMSsMWxHk725yiiHCCLfrh8O1z5QPOohDIaIeljMHgDF5CVlOqpeNLcJ80NK65_fV7S1UWPwZyNcweDIvdeL5kotwkIXjs9g0WibSO_cU-Ijy4Pwg6poS-6WGGnXqDacZer4yQ/1D3A7013-1.jpg
# [Error]Invalid image, not saving https://images.squarespace-cdn.com/content/v1/587d6250d482e9eee8c47666/1496644640891-S0V62M24QA0AUAKA9S5F/ke17ZwdGBToddI8pDm48kA_SSaoz4elkj-HsZd8gX3Z7gQa3H78H3Y0txjaiv_0fDoOvxcdMmMKkDsyUqMSsMWxHk725yiiHCCLfrh8O1z5QPOohDIaIeljMHgDF5CVlOqpeNLcJ80NK65_fV7S1UWPwZyNcweDIvdeL5kotwkIXjs9g0WibSO_cU-Ijy4Pwg6poS-6WGGnXqDacZer4yQ/1D3A7013-1.jpg
#
# [!] Issue getting: https://images.squarespace-cdn.com/content/v1/587d6250d482e9eee8c47666/1496644640891-S0V62M24QA0AUAKA9S5F/ke17ZwdGBToddI8pDm48kA_SSaoz4elkj-HsZd8gX3Z7gQa3H78H3Y0txjaiv_0fDoOvxcdMmMKkDsyUqMSsMWxHk725yiiHCCLfrh8O1z5QPOohDIaIeljMHgDF5CVlOqpeNLcJ80NK65_fV7S1UWPwZyNcweDIvdeL5kotwkIXjs9g0WibSO_cU-Ijy4Pwg6poS-6WGGnXqDacZer4yQ/1D3A7013-1.jpg
# [!] Error:: Invalid image, not saving https://images.squarespace-cdn.com/content/v1/587d6250d482e9eee8c47666/1496644640891-S0V62M24QA0AUAKA9S5F/ke17ZwdGBToddI8pDm48kA_SSaoz4elkj-HsZd8gX3Z7gQa3H78H3Y0txjaiv_0fDoOvxcdMmMKkDsyUqMSsMWxHk725yiiHCCLfrh8O1z5QPOohDIaIeljMHgDF5CVlOqpeNLcJ80NK65_fV7S1UWPwZyNcweDIvdeL5kotwkIXjs9g0WibSO_cU-Ijy4Pwg6poS-6WGGnXqDacZer4yQ/1D3A7013-1.jpg
#
# [%] Downloading Image #14 from https://www.kibrispdr.org/data/129/duck-bird-images-3.jpg
# [Error]Invalid image, not saving https://www.kibrispdr.org/data/129/duck-bird-images-3.jpg
#
# [!] Issue getting: https://www.kibrispdr.org/data/129/duck-bird-images-3.jpg
# [!] Error:: Invalid image, not saving https://www.kibrispdr.org/data/129/duck-bird-images-3.jpg
#
# [%] Downloading Image #14 from https://mnbirdatlas.org/graphics/photos/RUDU_MikeLentz_BBA.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://get.pxhere.com/photo/water-bird-animal-wildlife-beak-fauna-poultry-dentist-anatidae-duck-vertebrate-waterfowl-water-bird-animal-world-mallard-canard-duck-bird-aix-mandarin-ducks-bride-duck-aix-galericulata-ducks-geese-and-swans-ornamental-poultry-1143603.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://get.pxhere.com/photo/duck-bird-bird-water-bird-duck-water-animal-drake-feather-swim-bill-poultry-plumage-aquatic-animals-beautiful-1371121.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://www.kibrispdr.org/data/129/duck-bird-images-2.jpg
# [Error]Invalid image, not saving https://www.kibrispdr.org/data/129/duck-bird-images-2.jpg
#
# [!] Issue getting: https://www.kibrispdr.org/data/129/duck-bird-images-2.jpg
# [!] Error:: Invalid image, not saving https://www.kibrispdr.org/data/129/duck-bird-images-2.jpg
#
# [%] Downloading Image #17 from https://a-z-animals.com/media/2019/11/Duck-in-pond.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://www.wallpaperflare.com/static/814/472/998/ducks-wings-water-birds-canon-eos-6d-wallpaper.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://wallup.net/wp-content/uploads/2019/10/363951-wood-duck-bird-ducks-22.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://www.treehugger.com/thmb/ekORZ6wgGvhLfwfacUr9VErOEic=/3630x2420/filters:no_upscale():max_bytes(150000):strip_icc()/close-up-of-mandarin-duck-swimming-in-water--racconigi--cuneo--italy-977593824-7b8a89e6589c4a25bee2273cffba1965.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://getwallpapers.com/wallpaper/full/e/7/a/1372291-mallard-duck-wallpaper-1920x1080-for-android-tablet.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://get.pxhere.com/photo/bird-wildlife-wild-beak-fauna-poultry-duck-feathers-animals-females-vertebrate-waterfowl-water-bird-mallard-ducks-geese-and-swans-603506.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://i.redd.it/duzlg4run8e21.jpg
# [!] Issue getting: https://i.redd.it/duzlg4run8e21.jpg
# [!] Error:: HTTP Error 403: Blocked
# [%] Downloading Image #23 from https://www.allaboutbirds.org/guide/assets/og/75714891-1200px.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://get.pxhere.com/photo/bird-wing-animal-beak-fauna-poultry-duck-vertebrate-waterfowl-water-bird-mallard-canard-ducks-geese-and-swans-1010487.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://p0.pikist.com/photos/856/35/pacific-black-duck-duck-waddling-lawn-wildlife-waterfowl-bird-fauna-animal.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://www.rozenek.com/wp-content/uploads/2014/03/2013.04.07-Ducks-05.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://www.rozenek.com/wp-content/uploads/2014/03/2012.08.08-Whitlingham-02-1024x678.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://www.rozenek.com/wp-content/uploads/2014/03/2013.04.07-Ducks-03.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #29 from http://passnownow.com/wp-content/uploads/2015/06/duck.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://get.pxhere.com/photo/water-nature-bird-wing-flying-male-wildlife-beak-flight-colorful-fauna-poultry-drake-duck-vertebrate-waterfowl-water-bird-mallard-ducks-geese-and-swans-910177.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #31 from https://res.cloudinary.com/dk-find-out/image/upload/q_80,w_1920,f_auto/MA_00005156_ogecnj.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 35 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #32 from https://get.pxhere.com/photo/duck-mallard-bird-water-bird-meadow-water-duck-bird-nature-1370794.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #33 from https://cdn.pixabay.com/photo/2021/07/30/06/00/duck-6508753_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from https://c.pxhere.com/photos/a1/83/duck_mallard_bird_wildlife_waterfowl-626127.jpg!d
# [%] File Downloaded !
#
# [%] Downloading Image #35 from https://pixnio.com/free-images/2018/07/19/2018-07-19-17-03-44.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #36 from http://extension.msstate.edu/sites/default/files/news/2017/eo20161230_waterfowl.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #37 from https://get.pxhere.com/photo/bird-wing-reflection-beak-fauna-poultry-duck-vertebrate-waterfowl-water-bird-mallard-ducks-geese-and-swans-seaduck-164765.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #38 from https://get.pxhere.com/photo/bird-wing-wildlife-beak-fauna-poultry-duck-vertebrate-waterfowl-water-bird-mallard-canard-mergus-duck-bird-ducks-geese-and-swans-seaduck-730196.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #39 from https://www.ndow.org/wp-content/uploads/2021/10/G3G8361-copy.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #40 from https://cdn.pixabay.com/photo/2022/05/26/18/26/ducks-7223559_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #41 from https://cdn.pixabay.com/photo/2021/09/10/19/58/duck-6614083_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #42 from https://get.pxhere.com/photo/bird-wildlife-beak-fauna-birds-duck-vertebrate-ducks-waterfowl-water-bird-mallard-canard-wild-ducks-ducks-geese-and-swans-seaduck-1336674.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #43 from https://pixnio.com/free-images/fauna-animals/birds/duck-mallard-pictures/wood-ducks/wood-duck-drake-waterfowl-bird-is-seen-on-the-water.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 35 Images on Page 5.
#
# ===============================================
#
# [%] Downloading Image #44 from https://travisaudubon.org/home/wp-content/uploads/2018/01/APA_2016_Wood_Duck_Jess_Deitz_KK.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #45 from http://www.imageafter.com/dbase/images/nature_animals_birds/b3_birds002.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #46 from http://2.bp.blogspot.com/-jatV-ccvm1o/UClBGO0QlrI/AAAAAAAACYg/PMcmOPXsZoU/s1600/duck+bird.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #47 from https://www.rozenek.com/wp-content/uploads/2014/03/2013.04.07-Ducks-02.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 35 Images on Page 6.
#
# ===============================================
#
# [%] Downloading Image #48 from https://i.pinimg.com/originals/ad/b5/2a/adb52a111f156a38240634db9eec8f10.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #49 from https://animalcorner.org/wp-content/uploads/2015/02/ducks-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #50 from https://www.wallpapers13.com/wp-content/uploads/2018/07/Mandarin-Ducks-Bird-type-duck-from-East-Asia-China-imported-in-the-UK-Wallpapers-HD-3840x2160.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 7
#
# [%] Indexed 35 Images on Page 7.
#
# ===============================================
#
# [%] Downloading Image #51 from https://hawaiibirdingtrails.hawaii.gov/wp-content/uploads/Muscovy-Duck-female_Michelle-Moore-1024x1024.jpg
# [Error]Invalid image, not saving https://hawaiibirdingtrails.hawaii.gov/wp-content/uploads/Muscovy-Duck-female_Michelle-Moore-1024x1024.jpg
#
# [!] Issue getting: https://hawaiibirdingtrails.hawaii.gov/wp-content/uploads/Muscovy-Duck-female_Michelle-Moore-1024x1024.jpg
# [!] Error:: Invalid image, not saving https://hawaiibirdingtrails.hawaii.gov/wp-content/uploads/Muscovy-Duck-female_Michelle-Moore-1024x1024.jpg
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 35 Images on Page 8.
#
# ===============================================
#
# [%] Downloading Image #51 from https://pixnio.com/free-images/2019/03/15/2019-03-15-11-38-43-1200x900.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 35 Images on Page 9.
#
# ===============================================
#
#
#
# [!!]Indexing page: 10
#
# [%] Indexed 35 Images on Page 10.
#
# ===============================================
#
# [%] Downloading Image #52 from https://get.pxhere.com/photo/bird-cute-wildlife-fluffy-beak-small-yellow-chicken-fauna-poultry-birds-duck-duckling-vertebrate-waterfowl-water-bird-ducks-geese-and-swans-544230.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #53 from https://i.pinimg.com/originals/be/ea/50/beea506c1b3ed26d83f5131376d6d68e.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 11
#
# [%] Indexed 35 Images on Page 11.
#
# ===============================================
#
# [%] Downloading Image #54 from https://get.wallhere.com/photo/bird-duck-water-bird-ducks-geese-and-swans-beak-fauna-water-waterfowl-mallard-seaduck-canard-903660.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #55 from https://get.pxhere.com/photo/water-bird-wildlife-beak-fauna-close-up-duck-waterfowl-water-bird-mallard-birding-wood-duck-ducks-geese-and-swans-wildl-1181634.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #56 from https://cdn.pixabay.com/photo/2022/01/17/21/40/duck-6945872_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #57 from http://1.bp.blogspot.com/-5QeX2FgRlCA/UAT81tb-fXI/AAAAAAAAM-k/nw6pExCsKgg/s1600/Duck.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #58 from https://cdn.pixabay.com/photo/2022/06/28/17/04/duck-7290197_1280.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 12
#
# [%] Indexed 35 Images on Page 12.
#
# ===============================================
#
# [%] Downloading Image #59 from https://www.allaboutbirds.org/guide/assets/og/75711631-1200px.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 13
#
# [%] Indexed 35 Images on Page 13.
#
# ===============================================
#
# [%] Downloading Image #60 from https://cdn.pixabay.com/photo/2022/01/04/06/15/duck-6914285_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #61 from https://eskipaper.com/images/duck-6.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 14
#
# [%] Indexed 35 Images on Page 14.
#
# ===============================================
#
# [%] Downloading Image #62 from https://wallup.net/wp-content/uploads/2018/10/09/982783-animal-cute-baby-beauty-lake-water-bird-duck-duck-748x421.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 15
#
# [%] Indexed 35 Images on Page 15.
#
# ===============================================
#
# [%] Downloading Image #63 from https://wallup.net/wp-content/uploads/2016/01/238202-animals-duck-Tufted_duck-birds.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 16
#
# [%] Indexed 35 Images on Page 16.
#
# ===============================================
#
# [%] Downloading Image #64 from https://c.pxhere.com/photos/d4/e9/drake_duck_duck_bird_winter_water_bird_bird_nature_plumage-1371070.jpg!d
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 17
#
# [%] Indexed 35 Images on Page 17.
#
# ===============================================
#
# [%] Downloading Image #65 from http://pre-tend.com/wp-content/uploads/2015/02/mandarin-ducks.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 18
#
# [%] Indexed 35 Images on Page 18.
#
# ===============================================
#
# [%] Downloading Image #66 from https://www.rozenek.com/wp-content/uploads/2014/03/2013.04.07-Ducks-06.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 19
#
# [%] Indexed 35 Images on Page 19.
#
# ===============================================
#
# [%] Downloading Image #67 from https://ourplanetimages.com/wp-content/uploads/2021/10/Mallard-Duck-3-copy.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #68 from https://cdn.pixabay.com/photo/2020/08/09/13/19/duck-5475509_960_720.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 20
#
# [%] Indexed 35 Images on Page 20.
#
# ===============================================
#
# [%] Downloading Image #69 from https://wallup.net/wp-content/uploads/2016/01/43294-animals-duck-birds.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #70 from https://i.natgeofe.com/k/327b01e8-be2e-4694-9ae9-ae7837bd8aea/mallard-male-swimming_16x9.jpg?w=1200
# [%] File Downloaded !
#
# [%] Downloading Image #71 from https://abcbirds.org/wp-content/uploads/2019/09/BOTW-Facebook_Wood-Duck.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #72 from https://cdn.pixabay.com/photo/2022/11/02/00/08/duck-7563687_1280.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 21
#
# [%] Indexed 35 Images on Page 21.
#
# ===============================================
#
#
#
# [!!]Indexing page: 22
#
# [%] Indexed 35 Images on Page 22.
#
# ===============================================
#
# [%] Downloading Image #73 from https://cdn.pixabay.com/photo/2017/02/01/00/30/drake-2028582_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #74 from https://wallpapercave.com/wp/wp8395680.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 23
#
# [%] Indexed 35 Images on Page 23.
#
# ===============================================
#
# [%] Downloading Image #75 from https://global.canon/en/environment/bird-branch/photo-gallery/oshidori/img/gallery-oshidori-main@2x.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 24
#
# [%] Indexed 35 Images on Page 24.
#
# ===============================================
#
# [%] Downloading Image #76 from http://birdsflight.com/wp-content/uploads/2012/03/Tufted-Duck.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 25
#
# [%] Indexed 35 Images on Page 25.
#
# ===============================================
#
# [%] Downloading Image #77 from https://get.pxhere.com/photo/water-nature-bird-lake-pond-wildlife-swim-beak-couple-two-fauna-poultry-drake-birds-duck-animals-vertebrate-ducks-pair-waterfowl-water-bird-animal-world-togetherness-aquatic-animals-mallard-mallards-duck-bird-male-and-female-man-and-woman-woman-and-man-ducks-geese-and-swans-616418.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #78 from https://cdn.pixabay.com/photo/2023/06/12/06/03/duck-8057706_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #79 from https://c.pxhere.com/photos/40/bc/mandarin_duck_duck_water_feathers_bird_waterfowl-1093245.jpg!d
# [%] File Downloaded !
#
# [%] Downloading Image #80 from https://cdn.pixabay.com/photo/2022/10/01/08/26/duck-7491051_640.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #81 from https://www.wildbirdscoop.com/wp-content/uploads/2022/10/birds-that-look-like-ducks.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #82 from https://c.pxhere.com/photos/bb/a1/mallard_anas_platyrhynchos_drake_green_metallic_sparkle_bill_yellow-1362404.jpg!d
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 26
#
# [%] Indexed 35 Images on Page 26.
#
# ===============================================
#
# [%] Downloading Image #83 from http://ava7.com/w/birds/duck/duck-two-ducks-birds.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 27
#
# [%] Indexed 35 Images on Page 27.
#
# ===============================================
#
# [%] Downloading Image #84 from https://nas-national-prod.s3.amazonaws.com/styles/hero_cover_bird_page/s3/h_ring-necked-duck_004_spring_california_beckymatsubara_flickrcc-by-2.0_breeding-adult-male.jpg?itok=YeVayByG
# [%] File Downloaded !
#
# [%] Downloading Image #85 from https://www.rozenek.com/wp-content/uploads/2014/03/2013.04.07-Ducks-07.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 28
#
# [%] Indexed 35 Images on Page 28.
#
# ===============================================
#
# [%] Downloading Image #86 from https://cdn.pixabay.com/photo/2024/01/04/23/16/duck-8488539_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #87 from https://a-z-animals.com/media/2019/11/Duck-header.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #88 from https://images.squarespace-cdn.com/content/v1/587d6250d482e9eee8c47666/1510361356223-JA754RCD9XWRZU1EZ46E/ke17ZwdGBToddI8pDm48kA_SSaoz4elkj-HsZd8gX3Z7gQa3H78H3Y0txjaiv_0fDoOvxcdMmMKkDsyUqMSsMWxHk725yiiHCCLfrh8O1z5QPOohDIaIeljMHgDF5CVlOqpeNLcJ80NK65_fV7S1UWPwZyNcweDIvdeL5kotwkIXjs9g0WibSO_cU-Ijy4Pwg6poS-6WGGnXqDacZer4yQ/1D3A4050-1.jpg
# [Error]Invalid image, not saving https://images.squarespace-cdn.com/content/v1/587d6250d482e9eee8c47666/1510361356223-JA754RCD9XWRZU1EZ46E/ke17ZwdGBToddI8pDm48kA_SSaoz4elkj-HsZd8gX3Z7gQa3H78H3Y0txjaiv_0fDoOvxcdMmMKkDsyUqMSsMWxHk725yiiHCCLfrh8O1z5QPOohDIaIeljMHgDF5CVlOqpeNLcJ80NK65_fV7S1UWPwZyNcweDIvdeL5kotwkIXjs9g0WibSO_cU-Ijy4Pwg6poS-6WGGnXqDacZer4yQ/1D3A4050-1.jpg
#
# [!] Issue getting: https://images.squarespace-cdn.com/content/v1/587d6250d482e9eee8c47666/1510361356223-JA754RCD9XWRZU1EZ46E/ke17ZwdGBToddI8pDm48kA_SSaoz4elkj-HsZd8gX3Z7gQa3H78H3Y0txjaiv_0fDoOvxcdMmMKkDsyUqMSsMWxHk725yiiHCCLfrh8O1z5QPOohDIaIeljMHgDF5CVlOqpeNLcJ80NK65_fV7S1UWPwZyNcweDIvdeL5kotwkIXjs9g0WibSO_cU-Ijy4Pwg6poS-6WGGnXqDacZer4yQ/1D3A4050-1.jpg
# [!] Error:: Invalid image, not saving https://images.squarespace-cdn.com/content/v1/587d6250d482e9eee8c47666/1510361356223-JA754RCD9XWRZU1EZ46E/ke17ZwdGBToddI8pDm48kA_SSaoz4elkj-HsZd8gX3Z7gQa3H78H3Y0txjaiv_0fDoOvxcdMmMKkDsyUqMSsMWxHk725yiiHCCLfrh8O1z5QPOohDIaIeljMHgDF5CVlOqpeNLcJ80NK65_fV7S1UWPwZyNcweDIvdeL5kotwkIXjs9g0WibSO_cU-Ijy4Pwg6poS-6WGGnXqDacZer4yQ/1D3A4050-1.jpg
#
#
#
# [!!]Indexing page: 29
#
# [%] Indexed 35 Images on Page 29.
#
# ===============================================
#
#
#
# [!!]Indexing page: 30
#
# [%] Indexed 35 Images on Page 30.
#
# ===============================================
#
#
#
# [!!]Indexing page: 31
#
# [%] Indexed 35 Images on Page 31.
#
# ===============================================
#
# [%] Downloading Image #88 from https://www.wallpaperflare.com/static/814/472/998/ducks-wings-water-birds-canon-eos-6d-wallpaper-preview.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 32
#
# [%] Indexed 35 Images on Page 32.
#
# ===============================================
#
#
#
# [!!]Indexing page: 33
#
# [%] Indexed 35 Images on Page 33.
#
# ===============================================
#
# [%] Downloading Image #89 from https://wallup.net/wp-content/uploads/2016/10/12/183019-duck-birds-748x468.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #90 from https://eskipaper.com/images/bird-duck-photo-1.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 34
#
# [%] Indexed 35 Images on Page 34.
#
# ===============================================
#
# [%] Downloading Image #91 from https://justbirding.com/wp-content/uploads/2018/11/colorful-birds.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #92 from https://cdn.pixabay.com/photo/2023/10/18/07/20/duck-8323123_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #93 from https://www.allaboutbirds.org/guide/assets/og/75225851-1200px.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 35
#
# [%] Indexed 35 Images on Page 35.
#
# ===============================================
#
# [%] Downloading Image #94 from https://cdn.pixabay.com/photo/2022/03/03/20/05/duck-7045994_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #95 from https://birdwatchinghq.com/wp-content/uploads/2021/03/common-species-of-ducks-scaled-e1615316382853.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #96 from https://cdn.pixabay.com/photo/2021/12/02/18/03/duck-6841061_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #97 from http://2.bp.blogspot.com/-I2m78aG60q4/T_6SJFpx89I/AAAAAAAAKG8/J-1OthAKf3s/s1600/duck+bird+(15).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #98 from https://wallpaperaccess.com/full/5074854.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #99 from https://cdn.pixabay.com/photo/2022/11/11/12/52/duck-7584915_960_720.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 36
#
# [%] Indexed 35 Images on Page 36.
#
# ===============================================
#
#
#
# [!!]Indexing page: 37
#
# [%] Indexed 35 Images on Page 37.
#
# ===============================================
#
# [%] Downloading Image #100 from https://cdn.pixabay.com/photo/2015/01/25/21/22/duck-612108_1280.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 100 images.

# %%
import os

# Rename folders to "chicken" and "duck"
os.rename('images/chicken bird', 'images/chicken')
os.rename('images/duck bird', 'images/duck')

# %%
import splitfolders

# Now the path is valid and matches expected format
splitfolders.ratio('images', output="dataset", seed=1337, ratio=(.8, .1, .1))
# Out:
# Copying files: 200 files [00:00, 1972.18 files/s]

# %%
import os

for root, dirs, files in os.walk("dataset", topdown=True):
    for name in dirs:
        print(os.path.join(root, name))
# Out:
# dataset/val
# dataset/train
# dataset/test
# dataset/val/chicken
# dataset/val/duck
# dataset/train/chicken
# dataset/train/duck
# dataset/test/chicken
# dataset/test/duck

# %%
# Save dataset to Google Drive
# !cp -r /content/dataset /content/drive/MyDrive/chicken_duck_dataset/

# %%
IMG_SIZE = 224
BATCH_SIZE = 16

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train = train_datagen.flow_from_directory(
    "dataset/train",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary'
)

val = val_test_datagen.flow_from_directory(
    "dataset/val",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary'
)

test = val_test_datagen.flow_from_directory(
    "dataset/test",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False  # Important for evaluation
)
# Out:
# Found 159 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.

# %%
def show_samples(base_path, class_name, n=5):
    path = os.path.join(base_path, class_name)
    images = random.sample(os.listdir(path), n)

    plt.figure(figsize=(15, 3))
    for i, img_name in enumerate(images):
        img_path = os.path.join(path, img_name)
        img = Image.open(img_path)
        plt.subplot(1, n, i+1)
        plt.imshow(img)
        plt.title(class_name)
        plt.axis('off')
    plt.show()

# Show 5 samples from training set
show_samples("dataset/train", "chicken")
show_samples("dataset/train", "duck")

# %%
def count_images(folder):
    counts = {}
    for label in ['chicken', 'duck']:
        label_dir = os.path.join(folder, label)
        counts[label] = len(os.listdir(label_dir))
    return counts

splits = ['train', 'val', 'test']
dist_data = {}

for split in splits:
    dist_data[split] = count_images(f"dataset/{split}")

# Plot
fig, ax = plt.subplots(1, 3, figsize=(18, 4))
for i, split in enumerate(splits):
    ax[i].bar(dist_data[split].keys(), dist_data[split].values(), color=['orange', 'green'])
    ax[i].set_title(f'{split.capitalize()} set')
    ax[i].set_ylabel("Image count")
plt.suptitle("Class Distribution")
plt.show()

# %%
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model.trainable = False  # Freeze the base

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(64, activation='relu')(x)
output = Dense(1, activation='sigmoid')(x)  # Binary classification

model = Model(inputs=base_model.input, outputs=output)

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 112, 112,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 112, 112,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 112, 112,  │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 112, 112,  │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 112, 112,  │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 112, 112,  │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 113, 113,  │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 56, 56,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 56, 56,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 56, 56,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 56, 56,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 56, 56,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 56, 56,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 56, 56,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 56, 56,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 56, 56,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 56, 56,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 56, 56,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 56, 56,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 56, 56,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 57, 57,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 28, 28,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 28, 28,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 28, 28,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 28, 28,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 28, 28,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 28, 28,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 28, 28,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 28, 28,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 28, 28,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 28, 28,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 28, 28,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 28, 28,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 28, 28,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 28, 28,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 28, 28,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 28, 28,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 28, 28,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 28, 28,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 28, 28,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 28, 28,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 29, 29,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 14, 14,    │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │          0 │ block_6_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 14, 14,    │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 14, 14,    │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 14, 14,    │     24,576 │ block_6_project_… │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 14, 14,    │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 14, 14,    │          0 │ block_7_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 14, 14,    │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │          0 │ block_7_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 14, 14,    │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 14, 14,    │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 14, 14,    │          0 │ block_6_project_… │
# │                     │ 64)               │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 14, 14,    │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 14, 14,    │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 14, 14,    │          0 │ block_8_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 14, 14,    │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │          0 │ block_8_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 14, 14,    │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 14, 14,    │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 14, 14,    │          0 │ block_7_add[0][0… │
# │                     │ 64)               │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 14, 14,    │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 14, 14,    │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 14, 14,    │          0 │ block_9_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 14, 14,    │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │          0 │ block_9_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 14, 14,    │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 14, 14,    │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 14, 14,    │          0 │ block_8_add[0][0… │
# │                     │ 64)               │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 14, 14,    │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 14, 14,    │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 14, 14,    │          0 │ block_10_expand_… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 14, 14,    │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │          0 │ block_10_depthwi… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 14, 14,    │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 14, 14,    │        384 │ block_10_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 14, 14,    │     55,296 │ block_10_project… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 14, 14,    │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 14, 14,    │          0 │ block_11_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 14, 14,    │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │          0 │ block_11_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 14, 14,    │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 14, 14,    │        384 │ block_11_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 14, 14,    │          0 │ block_10_project… │
# │                     │ 96)               │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 14, 14,    │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 14, 14,    │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 14, 14,    │          0 │ block_12_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 14, 14,    │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │          0 │ block_12_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 14, 14,    │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 14, 14,    │        384 │ block_12_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 14, 14,    │          0 │ block_11_add[0][… │
# │                     │ 96)               │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 14, 14,    │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 14, 14,    │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 14, 14,    │          0 │ block_13_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 15, 15,    │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 7, 7, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 7, 7, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 7, 7, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 7, 7, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 7, 7, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 7, 7, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 7, 7, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 7, 7, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 7, 7, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 7, 7, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 7, 7, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 7, 7, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 7, 7, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 7, 7, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 7, 7, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 7, 7, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 7, 7, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 7, 7,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 7, 7,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 7, 7,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │     81,984 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │         65 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,340,033 (8.93 MB)
#  Trainable params: 82,049 (320.50 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
history = model.fit(
    train,
    validation_data=val,
    epochs=5
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
#  4/10 ━━━━━━━━━━━━━━━━━━━━ 3s 550ms/step - accuracy: 0.7513 - loss: 0.5011
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.8566 - loss: 0.3588 - val_accuracy: 1.0000 - val_loss: 0.0345
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 674ms/step - accuracy: 1.0000 - loss: 0.0306 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 808ms/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 680ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 841ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0032

# %%
# Predict on test set
pred_probs = model.predict(test)
pred_classes = (pred_probs > 0.5).astype("int32")

# True labels
true_classes = test.classes
class_labels = list(test.class_indices.keys())

# Classification Report
print(classification_report(true_classes, pred_classes, target_names=class_labels))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step
#               precision    recall  f1-score   support
#
#      chicken       1.00      1.00      1.00        10
#         duck       1.00      1.00      1.00        10
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20

# %% [markdown]
# ### Assignment Summary: Chicken vs Duck Image Classification Using Transfer Learning

# %% [markdown]
# - Collected approximately 100 images each of chickens and ducks using the `bing-image-downloader` library.
# - Organized the dataset into training, validation, and test sets using an 80/10/10 split.
# - Backed up the dataset to Google Drive for persistence.
# - Used **MobileNetV2** as the base model for transfer learning (pre-trained on ImageNet).
# - Removed the original classification head and added:
#   - Global Average Pooling layer
#   - Dense layer with ReLU activation
#   - Output layer with sigmoid activation for binary classification
# - Kept the base MobileNetV2 layers frozen during training (used as a fixed feature extractor).
# - Compiled the model using the **Adam optimizer** and **binary cross-entropy** loss.
# - Trained the model using image generators with basic data augmentation.
# - Evaluated model performance using a **classification report** (precision, recall, F1-score, and accuracy).
# - Visualized a few sample images and plotted the class distribution for all data splits.
# - Demonstrated the effectiveness of **transfer learning** for small-scale image classification tasks.
